# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    "state":list("abcd"),
    "year":range(1991,1995),
    "pop":range(6,10),
})
df
# Out:
#   state  year  pop
# 0     a  1991    6
# 1     b  1992    7
# 2     c  1993    8
# 3     d  1994    9

# %%
df.index = list("ABCD")
df.index.name = "索引"
df
# Out:
#    state  year  pop
# 索引
# A      a  1991    6
# B      b  1992    7
# C      c  1993    8
# D      d  1994    9

# %%
d = {
    "state":"e",
    "year":"1994",
    "pop":"10"
}
b = pd.Series(d)
b.name = "E"
df = df.append(b)
df
# Out:
#    state  year pop
# 索引
# A      a  1991   6
# B      b  1992   7
# C      c  1993   8
# D      d  1994   9
# E      e  1994  10

# %%
df = df.drop(['E'])
df
# Out:
#    state  year pop
# 索引
# A      a  1991   6
# B      b  1992   7
# C      c  1993   8
# D      d  1994   9

# %%
df["port"] = 1
df
# Out:
#    state  year pop  port
# 索引
# A      a  1991   6     1
# B      b  1992   7     1
# C      c  1993   8     1
# D      d  1994   9     1

# %%
df[(df["year"]==1991)|(df["year"]==1994)]
# Out:
#    state  year pop  port
# 索引
# A      a  1991   6     1
# D      d  1994   9     1

# %%
df[["state","year"]]
# Out:
#    state  year
# 索引
# A      a  1991
# B      b  1992
# C      c  1993
# D      d  1994

# %%
df.dtypes
# Out:
# state    object
# year     object
# pop      object
# port      int64
# dtype: object

# %%
df["pop"] = df["pop"].astype("int")
df.dtypes
# Out:
# state    object
# year     object
# pop       int32
# port      int64
# dtype: object

# %%
df["pop"] *= 2
df
# Out:
#    state  year  pop  port
# 索引
# A      a  1991   12     1
# B      b  1992   14     1
# C      c  1993   16     1
# D      d  1994   18     1

# %%
df = pd.read_excel("./香港酒店数据.xlsx")

# %%
df
# Out:
#                                                   字段1   字段2 字段3  字段4  \
# 0                 香港嘉湖海逸酒店(Harbour Plaza Resort City)  休闲度假  香港   元朗
# 1      香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)  浪漫情侣  香港   东区
# 2                                  香港碧荟酒店(The BEACON)  商务出行  香港  油尖旺
# 3                           香港湾仔帝盛酒店(Dorsett Wanchai)  浪漫情侣  香港   湾仔
# 4                                如心艾朗酒店(L‘hotel elan)  浪漫情侣  香港   观塘
# ..                                                ...   ...  ..  ...
# 415                       香港天天宾馆(TIN TIN GUEST HOUSE)  地铁周边  香港  油尖旺
# 416                               香港AMR宾馆(AMR Hostel)  地铁周边  香港  NaN
# 417  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  海滨风光  香港   荃湾
# 418  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  海滨风光  香港   荃湾
# 419                        香港花盈酒店(家庭旅馆)(Bloomy Hotel)  地铁周边  香港  油尖旺
#
#                        字段5  字段6      字段7    字段8
# 0               天水围 天恩路18号  4.6  17604.0  422.0
# ...

# %%
df.columns = ['名字','类型','城市','地区','地点','评分','评分人数','价格']
df.head()
# Out:
#                                                名字    类型  城市   地区  \
# 0             香港嘉湖海逸酒店(Harbour Plaza Resort City)  休闲度假  香港   元朗
# 1  香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)  浪漫情侣  香港   东区
# 2                              香港碧荟酒店(The BEACON)  商务出行  香港  油尖旺
# 3                       香港湾仔帝盛酒店(Dorsett Wanchai)  浪漫情侣  香港   湾仔
# 4                            如心艾朗酒店(L‘hotel elan)  浪漫情侣  香港   观塘
#
#               地点   评分     评分人数     价格
# 0     天水围 天恩路18号  4.6  17604.0  422.0
# 1       铜锣湾永兴街8号  4.5  12708.0  693.0
# 2     九龙旺角洗衣街88号  4.7    328.0  747.0
# 3  皇后大道东387-397号  4.4   5014.0  693.0
# 4       观塘创业街38号  4.6   3427.0  581.0

# %%
df[df["类型"]=="浪漫情侣"].head()
# Out:
#                                                 名字    类型  城市   地区  \
# 1   香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)  浪漫情侣  香港   东区
# 3                        香港湾仔帝盛酒店(Dorsett Wanchai)  浪漫情侣  香港   湾仔
# 4                             如心艾朗酒店(L‘hotel elan)  浪漫情侣  香港   观塘
# 5           香港隆堡柏宁顿酒店(Hotel Pennington by Rhombus)  浪漫情侣  香港   湾仔
# 20                        香港恒丰酒店(Prudential Hotel)  浪漫情侣  香港  油尖旺
#
#                地点   评分     评分人数     价格
# 1        铜锣湾永兴街8号  4.5  12708.0  693.0
# 3   皇后大道东387-397号  4.4   5014.0  693.0
# 4        观塘创业街38号  4.6   3427.0  581.0
# 5   铜锣湾边宁顿街13-15号  4.5   1938.0  869.0
# 20    尖沙嘴 弥敦道222号  4.5   8194.0  692.0

# %%
df[(df.类型=="浪漫情侣")&(df.地区=="湾仔")]
# Out:
#                                                     名字    类型  城市  地区  \
# 3                            香港湾仔帝盛酒店(Dorsett Wanchai)  浪漫情侣  香港  湾仔
# 5               香港隆堡柏宁顿酒店(Hotel Pennington by Rhombus)  浪漫情侣  香港  湾仔
# 23                         香港南洋酒店(South Pacific Hotel)  浪漫情侣  香港  湾仔
# 35                       香港遨舍卫兰轩(OZO Wesley Hong Kong)  浪漫情侣  香港  湾仔
# 67                     香港星网商务精品酒店(Wifi Boutique Hotel)  浪漫情侣  香港  湾仔
# 72                    香港丽骏酒店(Brighton Hotel Hong Kong)  浪漫情侣  香港  湾仔
# 123                       香港逸兰精品酒店(Lanson Place Hotel)  浪漫情侣  香港  湾仔
# 128                   香港珀丽酒店(Rosedale Hotel Hong Kong)  浪漫情侣  香港  湾仔
# 133                   英皇骏景酒店(香港湾仔店)(The Emperor Hotel)  浪漫情侣  香港  湾仔
# 159  香港华丽铜锣湾酒店(原香港华丽精品酒店)(Best Western Hotel Causew...  浪漫情侣  香港  湾仔
# 160  香港铜锣湾智选假日酒店(Holiday Inn Express Hong Kong Caus...  浪漫情侣  香港  湾仔
# 182                        香港问月酒店(Mira Moon Hong Kong)  浪漫情侣  香港  湾仔
# 183                        帆船精品酒店(VELA BOUTIQUE HOTEL)  浪漫情侣  香港  湾仔
# ...

# %%
df.isnull()
# Out:
#         名字     类型     城市     地区     地点     评分   评分人数     价格
# 0    False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 415  False  False  False  False  False  False  False  False
# 416  False  False  False   True  False   True   True  False
# 417  False  False  False  False  False  False  False  False
# 418  False  False  False  False  False  False  False  False
# 419  False  False  False  False  False  False  False  False
#
# [420 rows x 8 columns]

# %%
df[["地区","类型"]] = df[["地区","类型"]].fillna('其他')

# %%
df[["地区","类型"]]
# Out:
#       地区    类型
# 0     元朗  休闲度假
# 1     东区  浪漫情侣
# 2    油尖旺  商务出行
# 3     湾仔  浪漫情侣
# 4     观塘  浪漫情侣
# ..   ...   ...
# 415  油尖旺  地铁周边
# 416   其他  地铁周边
# 417   荃湾  海滨风光
# 418   荃湾  海滨风光
# 419  油尖旺  地铁周边
#
# [420 rows x 2 columns]

# %%
df["评分"].fillna(np.mean(df["评分"]))
# Out:
# 0      4.600000
# 1      4.500000
# 2      4.700000
# 3      4.400000
# 4      4.600000
#          ...
# 415    3.200000
# 416    4.283827
# 417    4.500000
# 418    4.500000
# 419    4.000000
# Name: 评分, Length: 420, dtype: float64

# %%
df[df["价格"].isna()].head(3)
# Out:
#                                                     名字    类型  城市   地区  \
# 227  香港红茶馆酒店(油麻地鸦打街店)(Bridal Tea House Hotel (Yau M...  浪漫情侣  香港  油尖旺
# 288   奥华·时尚精品酒店 - 中环(Ovolo Central – 2 Arbuthnot Road)  商务出行  香港  中西区
# 339                              香港洲际半岛酒店(MK-IP HOTEL)  地铁周边  香港   其他
#
#                   地点   评分    评分人数  价格
# 227     香港九龙油麻地鸦打街6号  4.1  5718.0 NaN
# 288         中环亚毕诺道2号  4.6    67.0 NaN
# 339  旺角上海街653-655号2楼  2.7   170.0 NaN

# %%
df["价格"].dropna(inplace=True)

# %%
df[df["价格"].isnull()].head(3)
# Out:
#                                                     名字    类型  城市   地区  \
# 227  香港红茶馆酒店(油麻地鸦打街店)(Bridal Tea House Hotel (Yau M...  浪漫情侣  香港  油尖旺
# 288   奥华·时尚精品酒店 - 中环(Ovolo Central – 2 Arbuthnot Road)  商务出行  香港  中西区
# 339                              香港洲际半岛酒店(MK-IP HOTEL)  地铁周边  香港   其他
#
#                   地点   评分    评分人数  价格
# 227     香港九龙油麻地鸦打街6号  4.1  5718.0 NaN
# 288         中环亚毕诺道2号  4.6    67.0 NaN
# 339  旺角上海街653-655号2楼  2.7   170.0 NaN
